# %%
import ROOT
from ROOT import gStyle
gStyle.SetOptStat(0)
# Out:
# Welcome to JupyROOT 6.26/08

# %%
myFile_0= ROOT.TFile.Open("/Users/bertabeltran/muon_data/data/DShaped/DShapedHole_SiPMV3_coin_2Ch0_3Ch1_5LSB_20fC_LSB/FILTERED/HcompassF_DShapedHole_SiPMV3_coin_2Ch0_3Ch1_5LSB_20fC_LSB_20230823_095640.root")

# %%
myFile_0.ls()
# Out:
# TFile**		/Users/bertabeltran/muon_data/data/DShaped/DShapedHole_SiPMV3_coin_2Ch0_3Ch1_5LSB_20fC_LSB/FILTERED/HcompassF_DShapedHole_SiPMV3_coin_2Ch0_3Ch1_5LSB_20fC_LSB_20230823_095640.root
#  TFile*		/Users/bertabeltran/muon_data/data/DShaped/DShapedHole_SiPMV3_coin_2Ch0_3Ch1_5LSB_20fC_LSB/FILTERED/HcompassF_DShapedHole_SiPMV3_coin_2Ch0_3Ch1_5LSB_20fC_LSB_20230823_095640.root
#   KEY: TDirectoryFile	Energy;1	Energy
#   KEY: TDirectoryFile	Time;1	Time
#   KEY: TDirectoryFile	PSD;1	PSD
#   KEY: TDirectoryFile	PSD_E;1	PSD_E
#   KEY: TTime	RealTime_0;1	object title
#   KEY: TTime	LiveTime_0;1	object title
#   KEY: TTime	RealTime_1;1	object title
#   KEY: TTime	LiveTime_1;1	object title

# %%
dir_0 = myFile_0.GetDirectory("Energy");

# %%
dir_0.ls()
# Out:
# TDirectoryFile*		Energy	Energy
#  KEY: TH1D	_F_EnergyCH0@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_0;1	object title
#  KEY: TH1D	_F_EnergyCH1@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_1;1	object title

# %%
hist_0 = dir_0.Get("_F_EnergyCH1@DT5751_1615;1")
c0 = ROOT.TCanvas("c0"," ",800,600)
hist_0.Rebin(7)
hist_0.Fit("gaus", "", "",700,1500)
gfit_0= hist_0.GetFunction("gaus")
m0=gfit_0.GetParameter(1)
m0_err= gfit_0.GetParError(1)
hist_0.Draw()
c0.Draw()
# Out:
#  FCN=129.418 FROM MIGRAD    STATUS=CONVERGED      85 CALLS          86 TOTAL
#                      EDM=2.86369e-09    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.7 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.49374e+03   5.58494e+00  -2.04313e-02   2.35978e-05
#    2  Mean         1.11399e+03   2.17016e+00   9.16039e-04  -9.75480e-06
#    3  Sigma        4.23534e+02   4.35337e+00   6.95106e-06   1.17328e-02
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c0

# %%
myFile_1= ROOT.TFile.Open("/Users/bertabeltran/muon_data/data/DShaped/DShapedHoles_NewBC408Scintillator_SiPMV3_4Chn0_5Chn1/FILTERED/HcompassF_DShapedHoles_NewBC408Scintillator_SiPMV3_4Chn0_5Chn1_20230830_113539.root")
dir_1 = myFile_1.GetDirectory("Energy");
dir_1.ls()
hist_1 = dir_1.Get("_F_EnergyCH1@DT5751_1615")
c1 = ROOT.TCanvas("c1"," ",800,600)
hist_1.Rebin(7)
hist_1.Fit("gaus","", "",1000,1500)
gfit_1= hist_1.GetFunction("gaus")
m1=gfit_1.GetParameter(1)
m1_err= gfit_1.GetParError(1)
hist_1.Draw()
c1.Draw()
# Out:
# TDirectoryFile*		Energy	Energy
#  KEY: TH1D	_F_EnergyCH0@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_0;1	object title
#  KEY: TH1D	_F_EnergyCH1@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_1;1	object title
#  FCN=81.902 FROM MIGRAD    STATUS=CONVERGED     122 CALLS         123 TOTAL
#                      EDM=1.75304e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     1.50714e+02   2.00739e+00   6.79494e-03  -4.76892e-06
#    2  Mean         1.12515e+03   2.66311e+01   4.47378e-02   6.13060e-08
#    3  Sigma        4.20566e+02   4.16249e+01   1.06299e-04  -2.89126e-03
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
myFile_3= ROOT.TFile.Open("/Users/bertabeltran/muon_data/data/DShaped/DShapedHoles_NewBC408Scintillator_SiPMV3_6Chn0_5Chn1/FILTERED/HcompassF_DShapedHoles_NewBC408Scintillator_SiPMV3_6Chn0_5Chn1_20230907_141220.root")
dir_3 = myFile_3.GetDirectory("Energy");
dir_3.ls()
hist_3 = dir_3.Get("_F_EnergyCH1@DT5751_1615")
c3 = ROOT.TCanvas("c3"," ",800,600)
hist_3.Rebin(7)
hist_3.Fit("gaus", "", "",1100,1800)
gfit_3= hist_3.GetFunction("gaus")
m3=gfit_3.GetParameter(1)
m3_err= gfit_3.GetParError(1)
hist_3.Draw()
c3.Draw()
# Out:
# TDirectoryFile*		Energy	Energy
#  KEY: TH1D	_F_EnergyCH0@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_0;1	object title
#  KEY: TH1D	_F_EnergyCH1@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_1;1	object title
#  FCN=144.137 FROM MIGRAD    STATUS=CONVERGED     118 CALLS         119 TOTAL
#                      EDM=1.15355e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.13643e+03   6.57059e+00   2.91743e-02   8.00940e-05
#    2  Mean         1.25391e+03   6.71954e+00   1.36326e-02   3.03773e-05
#    3  Sigma        5.05150e+02   8.43133e+00   2.02481e-05   3.61023e-02
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3

# %%
myFile_5= ROOT.TFile.Open("/Users/bertabeltran/muon_data/data/SiPM_angles/SIPMAngleTest_coin_5deg_20h/FILTERED/HcompassF_SIPMAngleTest_coin_5deg_20h_20230812_070529.root")
dir_5 = myFile_5.GetDirectory("Energy");
dir_5.ls()
hist_5 = dir_5.Get("_F_EnergyCH0@DT5751_1615")
c5 = ROOT.TCanvas("c5"," ",800,600)
hist_5.Rebin(7)
hist_5.Fit("gaus", "", "",500,1000)
gfit_5= hist_5.GetFunction("gaus")
m5=gfit_5.GetParameter(1)
m5_err= gfit_5.GetParError(1)
hist_5.Draw()
c5.Draw()
# Out:
# TDirectoryFile*		Energy	Energy
#  KEY: TH1D	_F_EnergyCH0@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_0;1	object title
#  KEY: TH1D	_F_EnergyCH1@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_1;1	object title
#  FCN=81.4983 FROM MIGRAD    STATUS=CONVERGED     105 CALLS         106 TOTAL
#                      EDM=1.04421e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.89296e+03   9.66922e+00   2.94037e-02   7.16758e-06
#    2  Mean         7.58893e+02   1.88575e+00   8.24804e-03   7.16058e-05
#    3  Sigma        3.37398e+02   4.77799e+00   2.40362e-05   4.89224e-03

# %%
c = ROOT.TCanvas("myCanvasName"," ",800,600)
#hist_1.Rebin(4)
#hist_coin.Rebin(4)

gStyle.SetOptStat(0)

hist_1.SetLineColor(3)
hist_1.SetFillColor(0)
hist_1.SetNormFactor(1)
hist_1.Draw("same")
hist_1.GetYaxis().SetTitleOffset(1.4) #1.2


hist_3.SetLineColor(4)
hist_3.SetFillColor(0)
hist_3.SetNormFactor(1)
hist_3.Draw("same")

hist_0.SetLineColor(1) # kMagenta = 616, 
hist_0.SetFillColor(0)
hist_0.SetNormFactor(1)
hist_0.Draw("same")



#c.SetLogy()
gStyle.SetOptStat(0)

leg = ROOT.TLegend(.7,.7,.9,.9)
leg.AddEntry(hist_0,"#splitline{Old scint, SiPM middle}{5 LSB Threshold}","L")

leg.AddEntry(hist_1,"#splitline{New scint, SiPM middle}{15 LSB Threshold}","L")

leg.AddEntry(hist_3,"#splitline{New scint, SiPM side}{20 LSB Threshold}","L")


leg.Draw()

tex=ROOT.TLatex(0.1,0.93,"Comparison between old BC-408 and new one (Luxium), Chn1 ");
tex.SetNDC();
tex.SetTextSize(0.04);
tex.Draw();

c.Draw()
c.SaveAs("/Users/bertabeltran/muon_data/data/Scint_comp.png");
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: myCanvasName
# Info in <TCanvas::Print>: png file /Users/bertabeltran/muon_data/data/Scint_comp.png has been created

# %%
import matplotlib.pyplot as plt
#plt.rcParams['figure.figsize'] = [5, 4]
#plt.rcParams['figure.dpi'] = 100
import numpy as np


x  = [0, 1, 3, 4, 5] 
y  = [m0,m1,m3,m4,m5]
yerr = [m0_err,m1_err,m3_err,m4_err,m5_err]

# plot:
fig, ax = plt.subplots()
#fig=plt.figure(figsize=(24,20), dpi= 100, facecolor='w', edgecolor='k')

#ax.errorbar(x, y, yerr, fmt='o', linewidth=2, capsize=6)
ax.errorbar(x, y, yerr,  marker='o', capsize=6)

ax.set(xlim=(-1, 6), ylim=(600, 1500))
ax.set(xlabel='Angle (deg)', ylabel='Mean of energy spectrum (ADC counts)',
       title='Mean of energy spectrum vs angle')

fig.savefig("/Users/bertabeltran/muon_data/data/SiPM_angles_graph2.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 8
#       4 import numpy as np
#       7 x  = [0, 1, 3, 4, 5]
# ----> 8 y  = [m0,m1,m3,m4,m5]
#       9 yerr = [m0_err,m1_err,m3_err,m4_err,m5_err]
#      11 # plot:
#
# NameError: name 'm4' is not defined
