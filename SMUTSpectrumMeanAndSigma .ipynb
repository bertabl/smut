# %%
import pandas as pd

df = pd.read_csv('/Users/bertabeltran/Downloads/Scintillators database - db.csv', usecols=['Thickness before wrapping  A (mm)','FirstMuSpectrumMean', 'FirstMuSpectrumSigma'])

# drop rows that contain NaN values
df = df.dropna()
print(df)
# Out:
#     Thickness before wrapping  A (mm)  FirstMuSpectrumMean  \
# 5                                9.45               1186.0
# 6                                9.39               1263.0
# 7                                9.31               1341.0
# 9                                9.35               1253.0
# 10                               9.42               1279.0
# 11                               8.93               1311.0
# 12                               8.66               1156.0
# 13                               9.00               1059.0
# 14                               9.30               1023.0
# 15                              10.02               1151.0
# 16                               9.25               1103.0
# 17                               8.70               1138.0
# 18                              10.30               1202.0
# 19                               8.81               1250.0
# 20                               9.29               1190.0
# 21                               9.72               1212.0
# 22                               8.84               1449.0
# 23                               8.86               1147.0
# 24                               9.29               1138.0
# 25                               8.92               1208.0
# 26                               9.04               1144.0
# 27                               9.60               1130.0
# 32                               9.99               1851.0
# 33                               9.27               1883.0
# 34                               9.62               2039.0
# 35                               9.55               2268.0
#
#     FirstMuSpectrumSigma
# 5                  288.0
# 6                  406.0
# 7                  309.0
# 9                  214.0
# 10                 384.0
# 11                 286.0
# 12                 250.0
# 13                 289.0
# 14                 225.0
# 15                 244.0
# 16                 275.0
# 17                 252.0
# 18                 308.0
# 19                 276.0
# 20                 349.0
# 21                 281.0
# 22                 446.0
# 23                 241.0
# 24                 238.0
# 25                 293.0
# 26                 255.0
# 27                 257.0
# 32                 472.0
# 33                 456.0
# 34                 542.0
# 35                 558.0

# %%
#https://saturncloud.io/blog/how-to-get-a-list-from-a-pandas-dataframe-column

# extract a list with means >1000 
thickness =  df[df['FirstMuSpectrumMean'] > 1000]['Thickness before wrapping  A (mm)'].tolist()
mean = df[df['FirstMuSpectrumMean'] > 1000]['FirstMuSpectrumMean'].tolist()
sigma = df[df['FirstMuSpectrumMean'] > 1000]['FirstMuSpectrumSigma'].tolist()
print(thickness)
print(mean)
print(sigma)
# Out:
# [9.45, 9.39, 9.31, 9.35, 9.42, 8.93, 8.66, 9.0, 9.3, 10.02, 9.25, 8.7, 10.3, 8.81, 9.29, 9.72, 8.84, 8.86, 9.29, 8.92, 9.04, 9.6, 9.99, 9.27, 9.62, 9.55]
# [1186.0, 1263.0, 1341.0, 1253.0, 1279.0, 1311.0, 1156.0, 1059.0, 1023.0, 1151.0, 1103.0, 1138.0, 1202.0, 1250.0, 1190.0, 1212.0, 1449.0, 1147.0, 1138.0, 1208.0, 1144.0, 1130.0, 1851.0, 1883.0, 2039.0, 2268.0]
# [288.0, 406.0, 309.0, 214.0, 384.0, 286.0, 250.0, 289.0, 225.0, 244.0, 275.0, 252.0, 308.0, 276.0, 349.0, 281.0, 446.0, 241.0, 238.0, 293.0, 255.0, 257.0, 472.0, 456.0, 542.0, 558.0]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(mean)
plt.xlabel('Mean')
plt.show()

# %%
#https://python-graph-gallery.com/83-basic-2d-histograms-with-matplotlib/
# libraries
import matplotlib.pyplot as plt
import numpy as np
 
fig, axes = plt.subplots(2, 1, figsize=(12,12))  
plt.subplots_adjust(wspace=0.25)
    
plt.sca(axes[0])   
h0=axes[0].hist2d(mean, sigma, bins=(20,20), cmap=plt.cm.BuPu)
fig.colorbar(h0[3])
axes[0].set_title('Mean vs. Sigma of the spectra')
axes[0].set_xlabel('Mean')
axes[0].set_ylabel('Sigma')

plt.sca(axes[1])   
h1=axes[1].hist2d(mean, thickness, bins=(20,20), cmap=plt.cm.BuPu)
fig.colorbar(h1[3])
axes[1].set_title('Mean of the spectra vs. its Thickness')
axes[1].set_xlabel('Mean')
axes[1].set_ylabel('thickness (mm) ')


plt. show()
