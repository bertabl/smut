# %%
import ROOT
from ROOT import gStyle
gStyle.SetOptStat(0)

# %%
myFile_0= ROOT.TFile.Open("/Users/bertabeltran/muon_data/data/SiPM_angles/SIPMAngleTest_coin_0deg_20h/FILTERED/HcompassF_SIPMAngleTest_coin_0deg_20h_20230810_044013.root")

# %%
myFile_0.ls()
# Out:
# TFile**		/Users/bertabeltran/muon_data/data/SiPM_angles/SIPMAngleTest_coin_0deg_20h/FILTERED/HcompassF_SIPMAngleTest_coin_0deg_20h_20230810_044013.root
#  TFile*		/Users/bertabeltran/muon_data/data/SiPM_angles/SIPMAngleTest_coin_0deg_20h/FILTERED/HcompassF_SIPMAngleTest_coin_0deg_20h_20230810_044013.root
#   KEY: TDirectoryFile	Energy;1	Energy
#   KEY: TDirectoryFile	Time;1	Time
#   KEY: TDirectoryFile	PSD;1	PSD
#   KEY: TDirectoryFile	PSD_E;1	PSD_E
#   KEY: TTime	RealTime_0;1	object title
#   KEY: TTime	LiveTime_0;1	object title
#   KEY: TTime	RealTime_1;1	object title
#   KEY: TTime	LiveTime_1;1	object title

# %%
dir_0 = myFile_0.GetDirectory("Energy");

# %%
dir_0.ls()
# Out:
# TDirectoryFile*		Energy	Energy
#  KEY: TH1D	_F_EnergyCH0@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_0;1	object title
#  KEY: TH1D	_F_EnergyCH1@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_1;1	object title

# %%
hist_0 = dir_0.Get("_F_EnergyCH0@DT5751_1615;1")
c0 = ROOT.TCanvas("c0"," ",800,600)
hist_0.Rebin(7)
hist_0.Fit("gaus", "", "",700,1600)
gfit_0= hist_0.GetFunction("gaus")
m0=gfit_0.GetParameter(1)
m0_err= gfit_0.GetParError(1)
hist_0.Draw()
c0.Draw()
# Out:
#  FCN=159.118 FROM MIGRAD    STATUS=CONVERGED      94 CALLS          95 TOTAL
#                      EDM=1.00788e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.06059e+03   5.73917e+00   2.79276e-02  -5.39182e-05
#    2  Mean         1.34025e+03   2.75780e+00   8.89355e-03   2.16762e-04
#    3  Sigma        4.20136e+02   2.92077e+00   9.36151e-06  -9.80063e-02
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c0

# %%
myFile_1= ROOT.TFile.Open("/Users/bertabeltran/muon_data/data/SIPM_angles/SIPMAngleTest_coin_1deg_20h/FILTERED/HcompassF_SIPMAngleTest_coin_1deg_20h_20230815_080114.root")
dir_1 = myFile_1.GetDirectory("Energy");
dir_1.ls()
hist_1 = dir_1.Get("_F_EnergyCH0@DT5751_1615")
c1 = ROOT.TCanvas("c1"," ",800,600)
hist_1.Rebin(7)
hist_1.Fit("gaus", "", "",750,1600)
gfit_1= hist_1.GetFunction("gaus")
m1=gfit_1.GetParameter(1)
m1_err= gfit_1.GetParError(1)
hist_1.Draw()
c1.Draw()
# Out:
# TDirectoryFile*		Energy	Energy
#  KEY: TH1D	_F_EnergyCH0@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_0;1	object title
#  KEY: TH1D	_F_EnergyCH1@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_1;1	object title
#  FCN=132.771 FROM MIGRAD    STATUS=CONVERGED      90 CALLS          91 TOTAL
#                      EDM=1.51468e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.05116e+03   5.90517e+00   2.58704e-02  -6.54531e-05
#    2  Mean         1.33943e+03   2.69511e+00   8.43728e-03   3.13048e-04
#    3  Sigma        4.11375e+02   3.09693e+00   9.74537e-06  -1.64185e-01
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
myFile_3= ROOT.TFile.Open("/Users/bertabeltran/muon_data/data/SIPM_angles/SIPMAngleTest_coin_3deg_20h/FILTERED/HcompassF_SIPMAngleTest_coin_3deg_20h_20230813_101629.root")
dir_3 = myFile_3.GetDirectory("Energy");
dir_3.ls()
hist_3 = dir_3.Get("_F_EnergyCH0@DT5751_1615")
c3 = ROOT.TCanvas("c3"," ",800,600)
hist_3.Rebin(7)
hist_3.Fit("gaus", "", "",600,1300)
gfit_3= hist_3.GetFunction("gaus")
m3=gfit_3.GetParameter(1)
m3_err= gfit_3.GetParError(1)
hist_3.Draw()
c3.Draw()
# Out:
# TDirectoryFile*		Energy	Energy
#  KEY: TH1D	_F_EnergyCH0@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_0;1	object title
#  KEY: TH1D	_F_EnergyCH1@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_1;1	object title
#  FCN=109.837 FROM MIGRAD    STATUS=CONVERGED     103 CALLS         104 TOTAL
#                      EDM=1.86046e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.40358e+03   7.28448e+00   2.70896e-02  -9.81720e-05
#    2  Mean         1.03088e+03   2.19010e+00   8.46984e-03   2.10941e-04
#    3  Sigma        3.87521e+02   3.66107e+00   1.43466e-05  -1.04502e-01
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3

# %%
myFile_4= ROOT.TFile.Open("/Users/bertabeltran/muon_data/data/SiPM_angles/SIPMAngleTest_coin_4deg_20h/FILTERED/HcompassF_SIPMAngleTest_coin_4deg_20h_20230816_062556.root")
dir_4 = myFile_4.GetDirectory("Energy");
dir_4.ls()
hist_4 = dir_4.Get("_F_EnergyCH0@DT5751_1615")
c4 = ROOT.TCanvas("c4"," ",800,600)
hist_4.Rebin(7)
hist_4.Fit("gaus", "", ""450,1000)
gfit_4= hist_4.GetFunction("gaus")
m4=gfit_4.GetParameter(1)
m4_err= gfit_4.GetParError(1)
hist_4.Draw()
c4.Draw()
# Out:
#   Cell In[91], line 7
#     hist_4.Fit("gaus", "", ""450,1000)
#                            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
myFile_5= ROOT.TFile.Open("/Users/bertabeltran/muon_data/data/SiPM_angles/SIPMAngleTest_coin_5deg_20h/FILTERED/HcompassF_SIPMAngleTest_coin_5deg_20h_20230812_070529.root")
dir_5 = myFile_5.GetDirectory("Energy");
dir_5.ls()
hist_5 = dir_5.Get("_F_EnergyCH0@DT5751_1615")
c5 = ROOT.TCanvas("c5"," ",800,600)
hist_5.Rebin(7)
hist_5.Fit("gaus", "", "",500,1000)
gfit_5= hist_5.GetFunction("gaus")
m5=gfit_5.GetParameter(1)
m5_err= gfit_5.GetParError(1)
hist_5.Draw()
c5.Draw()
# Out:
# TDirectoryFile*		Energy	Energy
#  KEY: TH1D	_F_EnergyCH0@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_0;1	object title
#  KEY: TH1D	_F_EnergyCH1@DT5751_1615;1
#  KEY: CalibrationCoefficient	Calibration_1;1	object title
#  FCN=81.4983 FROM MIGRAD    STATUS=CONVERGED     103 CALLS         104 TOTAL
#                      EDM=1.04438e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.89296e+03   9.66922e+00   2.94037e-02   7.16846e-06
#    2  Mean         7.58893e+02   1.88575e+00   8.24804e-03   7.16109e-05
#    3  Sigma        3.37398e+02   4.77799e+00   2.40362e-05   4.89310e-03
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c5

# %%
c = ROOT.TCanvas("myCanvasName"," ",800,600)
#hist_1.Rebin(4)
#hist_coin.Rebin(4)



hist_5.SetLineColor(6)
hist_5.SetFillColor(0)
#hist_5.SetNormFactor(1)
hist_5.Draw()
hist_5.GetYaxis().SetTitleOffset(1.5) #1.2

hist_0.SetLineColor(1) # kMagenta = 616, 
hist_0.SetFillColor(0)
#hist_0.SetNormFactor(1)
hist_0.Draw("same")


hist_3.SetLineColor(4)
hist_3.SetFillColor(0)
#hist_3.SetNormFactor(1)
hist_3.Draw("same")

hist_1.SetLineColor(3)
hist_1.SetFillColor(0)
#hist_1.SetNormFactor(1)
hist_1.Draw("same")

hist_4.SetLineColor(9)
hist_4.SetFillColor(0)
#hist_4.SetNormFactor(1)
hist_4.Draw("same")

#c.SetLogy()
gStyle.SetOptStat(0)

leg = ROOT.TLegend(.7,.7,.9,.9)
leg.AddEntry(hist_0,"SiPM $0^\circ$","L")

leg.AddEntry(hist_1,"SiPM $1^\circ$","L")

leg.AddEntry(hist_3,"SiPM $3^\circ$","L")

leg.AddEntry(hist_4,"SiPM $4^\circ$","L")

leg.AddEntry(hist_5,"SiPM $5^\circ$","L")
leg.Draw()

tex=ROOT.TLatex(0.3,0.93,"SiPM signal with different coupling angles");
tex.SetNDC();
tex.SetTextSize(0.04);
tex.Draw();

c.Draw()
c.SaveAs("/Users/bertabeltran/muon_data/data/SiPM_angles_new.png");
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: myCanvasName
# Info in <TCanvas::Print>: png file /Users/bertabeltran/muon_data/data/SiPM_angles_new.png has been created

# %%
import matplotlib.pyplot as plt
#plt.rcParams['figure.figsize'] = [5, 4]
#plt.rcParams['figure.dpi'] = 100
import numpy as np


x  = [0, 1, 3, 4, 5] 
y  = [m0,m1,m3,m4,m5]
yerr = [m0_err,m1_err,m3_err,m4_err,m5_err]

# plot:
fig, ax = plt.subplots()
#fig=plt.figure(figsize=(24,20), dpi= 100, facecolor='w', edgecolor='k')

#ax.errorbar(x, y, yerr, fmt='o', linewidth=2, capsize=6)
ax.errorbar(x, y, yerr,  marker='o', capsize=6)

ax.set(xlim=(-1, 6), ylim=(600, 1500))
ax.set(xlabel='Angle (deg)', ylabel='Mean of energy spectrum (ADC counts)',
       title='Mean of energy spectrum vs angle')

fig.savefig("/Users/bertabeltran/muon_data/data/SiPM_angles_graph2.png")
plt.show()
